# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading csv file

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# # Handling missing values
# Handling missing values in columns

# %%
df_missing_columns = df.isnull().sum()
df_missing_columns
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# We have no missing values in any of the columns in the given DATASET. Hence,there is no problem with null values

# %% [markdown]
# # Checking the distribution of class

# %%
classes = df['Class'].value_counts()
classes
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
normal_share = classes[0] / df['Class'].count()
normal_share
# Out:
# 0.9982725143693799

# %%
fraud_share = classes[1] / df['Class'].count()
fraud_share
# Out:
# 0.001727485630620034

# %% [markdown]
# If we convert the normal_share and fraud_share into percentages then the normal_share is 99.82% and the fraud_share is only 0.17%.

# %%
# Bar plotting the number of fraudulent vs non-fraudulent transcations
sns.countplot(x='Class',data = df)
plt.title('No of Non-fraudulent vs fraudulent transcations')
plt.show()

# %%
#bar plotting the percentage of fraudulent and non-fraudulent transactions
fraud_percentage = {'Class':['Non-Fraudulent', 'Fraudulent'], 'Percentage':[normal_share, fraud_share]} 
df_fraud_percentage = pd.DataFrame(fraud_percentage) 
sns.barplot(x='Class',y='Percentage', data=df_fraud_percentage)
plt.title('Percentage of Non-fraudulent vs fraudulent transcations')
plt.show()

# %% [markdown]
# # Observe the distribution of classes

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#Creating non fradulent dataframe
data_non_fraud = df[df['Class'] == 0]

# %%
#Creating fraudulent dataframe
data_fraud = df[df['Class'] == 1]

# %%
#Plotting distribution
plt.figure(figsize = (8,5))
a = sns.distplot(data_non_fraud['Time'],label = 'Non fraudulent',hist=False)
a = sns.distplot(data_fraud['Time'],label = 'fraudulent',hist = False)
a.set(xlabel = 'Time B/W the transaction and the first transaction')
plt.legend()
plt.show()

# %% [markdown]
# We do not see any pattern for the non-fraudulent and fraudulent transactions with respect to time.So,we can drop the Time column

# %%
# Dropping the Time column
df.drop('Time',axis=1,inplace = True)

# %%
df.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# ...

# %% [markdown]
# # observe the distribution of class with amount

# %%
#plotting the distribution with amount
plt.figure(figsize=(8,5))
ax = sns.distplot(data_non_fraud['Time'],label = 'non-fraudulent',hist=False)
ax = sns.distplot(data_fraud['Amount'],label = 'fraudulent',hist = False)
ax.set(xlabel='transaction Amount')
plt.legend()
plt.show()

# %% [markdown]
# # Checking the Skewness

# %%
# list of columns
cols = df.columns
cols
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class'],
#       dtype='object')

# %%
# plotting the distribution of the variables of all columns
plt.figure(figsize=(17,28))
for i,col in enumerate(cols[:-1],1):
    plt.subplot(6,5,i)
    sns.distplot(df[col])
    plt.title(col+' '+str(df[col].skew()))
plt.show()

# %% [markdown]
# # Explanatory Data Analysis

# %%
df.hist(figsize=(20,20),color='green')
plt.show()

# %% [markdown]
# # CORRELATION

# %%
plt.figure(figsize=(10,8))
corr = df.corr()
sns.heatmap(corr,cmap='BuPu')
# Out:
# <Axes: >

# %% [markdown]
# # Splitting the Data set

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['Class'],axis=1)

# %%
y = df['Class']

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state = 0)

# %%
X_test.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 183484 -0.323334  1.057455 -0.048341 -0.607204  1.259821 -0.091761  1.159101
# 255448 -0.349718  0.932619  0.142992 -0.657071  1.169784 -0.733369  1.009985
# 244749 -1.614711 -2.406570  0.326194  0.665520  2.369268 -1.775367 -1.139049
# 63919  -2.477184  0.860613  1.441850  1.051019 -1.856621  2.078384  0.510828
# 11475   1.338831 -0.547264  0.737389 -0.212383 -1.110039 -0.525744 -0.801403
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 183484 -0.124335 -0.174640 -1.644401  ...  0.186409 -0.207098 -0.433890
# 255448 -0.071069 -0.302083 -1.192404  ... -0.096502 -0.271537 -0.833209
# 244749  0.329904  0.903813 -0.219013  ...  0.419835  0.701399  1.134489
# 63919  -0.243399 -0.260691  0.133040  ... -0.987790  0.810408  0.692245
# 11475  -0.063672  0.997276  0.113386  ... -0.126871 -0.139436 -0.074719
#
# ...

# %%
X_train.head()
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 161145 -0.132066  0.107044 -0.650588 -0.996032  1.814333  1.740740  0.496852
# 204520  2.125994  0.014207 -1.514760  0.115021  0.598510 -0.333235  0.199289
# 182659 -0.086694  0.166240  1.573127  0.687266  0.222359  1.102606  1.575093
# 25117   1.352339 -0.534984  0.555143 -0.629355 -1.144170 -0.852967 -0.642128
# 227642 -1.526760  0.647782  0.615391 -0.561114  0.836950 -0.514251  0.984325
#
#               V8        V9       V10  ...       V20       V21       V22  \
# 161145  0.633016  0.017181 -0.362707  ... -0.062612 -0.062489  0.005292
# 204520 -0.264353  0.384111  0.028747  ... -0.086076 -0.329368 -0.788150
# 182659 -1.098608  0.763887  1.404677  ...  0.052960  0.015324  1.063663
# 25117  -0.032659 -0.654482  0.619206  ... -0.066712 -0.014814 -0.180379
# 227642 -0.097430 -0.062634 -1.033567  ... -0.073333 -0.221533 -0.393158
#
# ...

# %% [markdown]
# # Model Creation

# %% [markdown]
# # By using logistic regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
l = LogisticRegression()

# %%
model = l.fit(X_train,y_train)

# %%
prediction = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,prediction)
# Out:
# 0.9991573329588147

# %% [markdown]
# # By using random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
X1 = df.drop(['Class'],axis=1)

# %%
y1 = df['Class']

# %%
X1_train,X1_test,y1_train,y1_test = train_test_split(X1,y1,test_size=0.3,random_state=0)

# %%
r = RandomForestClassifier()

# %%
model1 = r.fit(X1_train,y1_train)

# %%
prediction1 = model1.predict(X1_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y1_test,prediction1)
# Out:
# 0.9995318516437859

# %% [markdown]
# # Model's performance using metrics in logistic regression

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test,prediction))
# Out:
# [[85282    14]
#  [   58    89]]

# %%
print(classification_report(y_test,prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.86      0.61      0.71       147
#
#     accuracy                           1.00     85443
#    macro avg       0.93      0.80      0.86     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# # Model's performance using metrics in random forest classifier

# %%
print(confusion_matrix(y1_test,prediction1))
# Out:
# [[85289     7]
#  [   33   114]]

# %%
print(classification_report(y1_test,prediction1))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.94      0.78      0.85       147
#
#     accuracy                           1.00     85443
#    macro avg       0.97      0.89      0.93     85443
# weighted avg       1.00      1.00      1.00     85443

# %% [markdown]
# # Model's performance considering Oversampling

# %%
from imblearn.over_sampling import SMOTE
from sklearn.ensemble import RandomForestClassifier

# %%
smote = SMOTE(random_state = 0)

# %%
X1_resampled, y1_resampled = smote.fit_resample(X1_train, y1_train)

# %%
model2 = RandomForestClassifier()
model2.fit(X1_resampled, y1_resampled)
# Out:
# RandomForestClassifier()

# %%
y_pred_resampled = model2.predict(X1_test)

# %%
print(confusion_matrix(y1_test,y_pred_resampled))
# Out:
# [[85281    15]
#  [   26   121]]

# %%
print(classification_report(y1_test,y_pred_resampled))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     85296
#            1       0.89      0.82      0.86       147
#
#     accuracy                           1.00     85443
#    macro avg       0.94      0.91      0.93     85443
# weighted avg       1.00      1.00      1.00     85443
